# %% [markdown]
# # 🧪 Lab Workbook: Phosphate Calibration
# ### Experiment 1D -- Environmental Audit of Possible Phosphate Contamination
#
#
# **Name:** _________________________
#
# **Date:** __________________________
#
#
# ---
#
#
#
# **Guided workbook** -- you write the code; this notebook gives structure, tips, and prompts.
#
# Developed by Valentina Erastova, University of Edinburgh
#
# Contact: valentina.erastova@ed.ac.uk

# %% [markdown]
# ---
# ## How to use this notebook
#
# 1. Open in **Edina Noteable** (`Standard Python 3` kernel): https://noteable.edina.ac.uk/launch
# 2. Read each step before writing code.
# 3. Use the **empty code cells** the answers are not filled in for you.
# 4. Stuck? Use the **tips** and **ELM prompts** - ask for hints, not the full solution.
# 5. Check units and chemical sense after every step.
#
#
# XXXXX TO FIX AS NEEDED XXXXXX
#
#
# **Get the files from Git:**
# ```text
# git clone https://github.com/Erastova-group/PgT-Python-Vibe.git
# ```
# Open `Phosphate/phosphate_calibration_workbook.ipynb`.
#
# The lab handout is in the same folder: `Phosphate calibration plot .docx`.

# %% [markdown]
# ---
# ## 🔄 Quick reminder (from the workshop)
#
# You need: **variables**, **lists or pandas**, **matplotlib plots**, **ELM for help**.
#
# **Beer-Lambert:** $A = \epsilon l c$ -- if path length is fixed, absorbance vs concentration should be linear.
#
# **ELM workflow:** prompt $\rightarrow$ paste code $\rightarrow$ run $\rightarrow$ read $\rightarrow$ fix. Ask for *hints* or *one step at a time* if you want to learn, not just copy.

# %% [markdown]
# ---
# ## 📋 What you are analysing
#
# - **Standards:** 0, 2, 4, 6, 8, 10 mL of stock pipetted into 50 mL flasks (+ blank)
# - **Stock:** $2.00 \times 10^{-3}\ \text{mg mL}^{-1}$
# - **Unknown:** cow urine (pre-diluted $\times 10$), 10 mL into 50 mL flasks, triplicate absorbance at 880 nm
# - **Big question:** If 100 cows $\times$ 13 L urine/day all reach Loch of the Lowes ($5.5 \times 10^{6}\text{ m}^3$, starting at $5.00\ \mu\text{g L}^{-1}$), how long until phosphate exceeds **$0.025\ \text{mg L}^{-1}$**?

# %% [markdown]
# | Step | Your task |
# |---|---|
# | 1 | Calculate standard concentrations |
# | 2 | Enter absorbance data and build tables |
# | 3 | Plot the calibration curve |
# | 4 | Fit a straight line and report $R^2$ |
# | 5 | Find urine phosphate concentration |
# | 6 | Estimate environmental impact on Loch of the Lowes |
# | 7 | Evaluate your assumptions |
#
#
#
# ---
# ## Step 1 -- Standard concentrations
#
# **Your task:** Calculate the phosphate concentration ($\text{mg L}^{-1}$) in each 50 mL standard flask.
#
# **Tips:**
# - Convert stock: $2.00 \times 10^{-3}\ \text{mg mL}^{-1}$ = **$2.00\ \text{mg L}^{-1}$**
# - Use **$C_1 V_1 = C_2 V_2$** with $V_2$ = 50 mL for each pipetted volume
# - You should get six values: blank = 0, then increasing concentrations
#
# **Check:** Does each concentration double when you double the pipetted volume?

# %%
# Given values -- do not change unless your demonstrator says otherwise
stock_conc_mg_per_L = 2.00e-3 * 1000   # mg/mL -> mg/L
final_volume_mL = 50.0
pipette_volumes_mL = [0, 2, 4, 6, 8, 10]

# %%
# ✏️ YOUR CODE -- calculate concentration (mg L^{-1}) for each standard
# Store results in a list called standard_conc_mg_per_L

# %% [markdown]
# **Tip:** A `for` loop over `pipette_volumes_mL` works well. Or a list comprehension.
#
# ### 🤖 ELM prompt (if stuck):
# > *I have stock concentration $2.00\ \text{mg L}^{-1}$ and pipette volumes [0,2,4,6,8,10] mL into 50 mL flasks. Give me a hint for calculating each final concentration using $C_1 V_1$=$C_2 V_2$ -- don't write the full code yet.*

# %% [markdown]
# ---
# ## Step 2 -- Enter your absorbance data
#
# **Your task:** Build two tables (pandas DataFrames are easiest):
# 1. **Standards** -- flask label, pipetted volume, concentration, absorbance at 880 nm
# 2. **Unknowns** -- three replicate absorbance readings
#
# **Tips:**
# - Copy absorbance values from your lab notebook
# - Name your dataframes `standards` and `unknowns` so later cells match
# - Use `display(df)` to print tables neatly
#
# **Imports you will need:** `pandas`, and `display` from `IPython.display`

# %%
# ✏️ YOUR CODE -- imports, data entry, and display tables
# Create variables: standards and unknowns

# %% [markdown]
# ### 🤖 ELM prompt:
# > *I have lists of standard concentrations and absorbances (6 values) and three unknown absorbances. Show me how to put these into two pandas DataFrames called `standards` and `unknowns` with sensible column names. Beginner-friendly, for a Jupyter notebook.*

# %% [markdown]
# ---
# ## Step 3 -- Calibration plot
#
# **Your task:** Plot absorbance (y) vs concentration (x) for the standards.
#
# **Tips:**
# - `import matplotlib.pyplot as plt`
# - Use markers (`'o'`) not just a line -- these are measurements
# - Label axes with **units**; add a title and grid
# - Points should trend upward; blank should be near zero

# %%
# ✏️ YOUR CODE -- calibration plot

# %% [markdown]
# ### 🤖 ELM prompt:
# > *My dataframe `standards` has columns `concentration_mg_per_L` and `absorbance_880nm`. Write matplotlib code for a scatter/line plot with axis labels, title, and grid. Beginner-friendly.*

# %% [markdown]
# ---
# ## Step 4 -- Linear fit and $R^2$
#
# **Your task:** Fit **$A = mc + b$** and report slope ($m$), intercept ($b$), and $R^2$. Overlay the fit on your plot.
#
# **Tips:**
# - `numpy.polyfit(x, y, 1)` returns slope and intercept
# - $R^2$ measures how linear the data are (1 = perfect straight line)
# - Slope $\approx$ how much absorbance changes per $\text{mg L}^{-1}$; intercept should be small
#
# **🧠 Pause:** Does the fit look right? Is $R^2$ close to 1?

# %%
# ✏️ YOUR CODE -- linear fit, print equation and $R^2$, plot with trendline

# %% [markdown]
# ### 🤖 ELM prompt:
# > *I have x = concentration and y = absorbance arrays. Show me how to use np.polyfit, calculate $R^2$, print the equation, and plot the data with a dashed trendline. Beginner-friendly.*
#
# **Harder option (no AI):** Look up `np.polyfit` in the workshop notebook (`chemistry_python_intro.ipynb`, Task 2.3).

# %% [markdown]
# ---
# ## Step 5 -- Unknown concentration and dilution
#
# **Your task:**
# 1. Rearrange the calibration line to find $c$ from each unknown absorbance: $c = (A - b) / m$
# 2. Calculate mean (and optionally std) across triplicates in the **50 mL treated flask**
# 3. **Work out the total dilution factor** back to original urine and correct the concentration
#
# **Tips -- trace the dilutions:**
# - Urine was pre-diluted **$\times 10$** before you received it
# - You pipetted **10 mL** into a **50 mL** flask $\rightarrow$ what is that dilution factor?
# - Multiply the flask concentration by **all** dilution factors to get original urine $\text{mg L}^{-1}$
#
# **Check:** Write the dilution factor as a number in your code and add a comment explaining it.

# %%
# ✏️ YOUR CODE -- unknown concentrations and dilution correction
# You need variables from Step 4: slope, intercept

# %% [markdown]
# ### 🤖 ELM prompt:
# > *I have slope and intercept from a calibration line and three unknown absorbances in dataframe `unknowns`. Give me a hint for rearranging A = slope*c + intercept to find c, then correcting for a $\times 10$ pre-dilution and 10 mL into 50 mL. Don't give full code -- just the steps.*

# %% [markdown]
# ---
# ## Step 6 -- Environmental impact
#
# **Your task:** Estimate how many **days** until loch phosphate reaches the SEPA safe limit.
#
# **Given (use these):**
# | Quantity | Value |
# |---|---|
# | Loch volume | $5.5 \times 10^{6}\text{ m}^3$ |
# | Initial [phosphate] | $5.00\ \mu\text{g L}^{-1}$ |
# | Safe limit | $0.025\ \text{mg L}^{-1}$ |
# | Cows | 100 |
# | Urine per cow per day | 13 L |
# | Assumption | All daily urine enters loch; instant mixing |
#
# **Tips -- plan before coding:**
# 1. Convert units ($\mu\text{g L}^{-1} \rightarrow \text{mg L}^{-1}$; $\text{m}^3 \rightarrow \text{L}$)
# 2. Use **your** urine phosphate concentration from Step 5
# 3. Daily phosphate mass added = daily urine volume $\times$ urine concentration
# 4. Mass needed to reach safe limit = ($\mathrm{safe} - \mathrm{initial}$) $\times$ loch volume
# 5. Days = mass still needed / daily mass added

# %%
# ✏️ YOUR CODE -- environmental calculation
# Use your conc_urine_mg_per_L (or equivalent) from Step 5

# %% [markdown]
# ### 🤖 ELM prompt:
# > *I measured urine phosphate as [YOUR VALUE] $\text{mg L}^{-1}$. Loch is $5.5 \times 10^{6}\text{ m}^3$ at $5.00\ \mu\text{g L}^{-1}$ phosphate; safe limit $0.025\ \text{mg L}^{-1}$. 100 cows $\times$ 13 L urine/day all enter the loch. Give me the calculation steps with units -- I'll write the Python myself.*

# %% [markdown]
# ---
# ## Step 7 -- Evaluation
#
# Write short answers in the cell below (double-click to edit):
#
# 1. How realistic is your time estimate? What did you assume?
# 2. How precise were your triplicate unknowns?
# 3. Was Beer-Lambert valid over your concentration range?
# 4. What important information was **missing** for a real environmental report?
#
# ---
# ## ✅ Before you submit
#
# - [ ] Every code cell runs without errors
# - [ ] Calibration plot and $R^2$ shown
# - [ ] Urine concentration includes dilution factors
# - [ ] Environmental estimate with units
# - [ ] Evaluation written
# - [ ] LEARN quiz completed within one week

# %% [markdown]
# ### Your evaluation
#
# 1.
#
# 2.
#
# 3.
#
# 4.
